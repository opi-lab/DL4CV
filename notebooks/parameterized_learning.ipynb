# %% [markdown]
# <a href="https://colab.research.google.com/github/opi-lab/DL4CV/blob/main/notebooks/parameterized_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Parameterized Learning and Linear Classiﬁcation
#
# Andrés Marrugo, 2022
#
# Notes based on Deep Learning for Computer Vision by Adrian Rosenbrock

# %% [markdown]
# Parameterization is the process of deﬁning the necessary parameters of a given model. In the task of machine learning, parameterization involves deﬁning a problem in terms of four key components: data, a scoring function, a loss function, and weights and biases.
#
# We will follow the chapter 8 on parameterized learning with a simple example on how to classify an input image from a linear model.

# %%
# import the necessary packages
import numpy as np
import cv2
from skimage import io
from google.colab.patches import cv2_imshow # for image display

# %%
# Let's load the test image
url = "https://github.com/opi-lab/DL4CV/raw/main/data/beagle.png"

image = io.imread(url)
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2_imshow(image2)
# Out:
# <PIL.Image.Image image mode=RGB size=500x336 at 0x7F745CF62390>
